# %% [markdown]
# # Visualiserar medarbetares tillhörighet i olika team

# %%
import pandas as pd

# %%
teammembers = pd.read_excel("data/data.xlsx", 'TeamMembers')
teammembers.drop(['Typ', 'Användare','Department', 'Aktiv'], axis=1, inplace=True)
teammembers.dropna(thresh=2, inplace=True)
teammembers
# Out:
#                             Grupp                            E-post
# 1                  UK Development  Paul.Wadner-Holmes@skanska.co.uk
# 3                SE HR Pilotgrupp        torbjorn.kruger@skanska.se
# 4                Vsaa Förvaltning        susanne.sjoblom@skanska.se
# 8       UK User Access & Security           marc.winn@skanska.co.uk
# 10                 SE HR New Hire                isaken03@gmail.com
# ...                           ...                               ...
# 16352         SE Customer Support        ingela.sandberg@skanska.se
# 16353           HR Administration       pernilla.nilsson@skanska.se
# 16354              SE HR New Hire         micke.olsson@limegreen.se
# 16356  FI ITSM Littera hyväksyntä           esa.vaananen@skanska.fi
# 16357            SE HR Pilotgrupp        cecilia.mostrom@skanska.se
#
# [11220 rows x 2 columns]

# %%
services = pd.read_excel("data/data.xlsx", 'Services')
services["Grupp"] = services["Supportgrupp (2nd)"]
services
# Out:
#                                                 Namn  \
# 0    Credit Safe - supplier import and credit report
# 1                                   CAD/BIM Tools SE
# 2               ACC SE - Autodesk Construction Cloud
# 3                         Web County Orders Nyköping
# 4                             Fusion Finance Finland
# ..                                               ...
# 117                         Birkamark Infrastructure
# 118                                          Hjärnan
# 119                                Power Platform SE
# 120                                           RPA AM
# 121                         Fusion Database Platform
#
#                            Ägare                              Ansvarig  \
# 0    Jessica Axelsson (SE343575)          Alexander Janving (SE327069)
# 1         Tomas Eklöf (SE316256)                Tomas Eklöf (SE316256)
# 2     Elina Wahlström (SE419080)                Tomas Eklöf (SE316256)
# 3     Gabriella Rosén (SE402276)            Gabriella Rosén (SE402276)
# 4    Martin Lönnqvist (FI249271)             Kari Salokangas (FI60076)
# ..                           ...                                   ...
# 117  Jessica Axelsson (SE343575)                Tomas Eklöf (SE316256)
# 118   Mikael Ahlqvist (SE149184)           Krister Normark (SE340049C)
# 119     Karam Chammas (SE313646)             Kajsa Araskoug (SE427717)
# 120  Jessica Axelsson (SE343575)           Brindaduti Maiti (SE342434)
# 121   Mikael Ahlqvist (SE149184)  Maria Jose Campo Martinez (SE312618)
#
#                   Förvaltningsobjekt            Supportgrupp (3rd)  \
# 0               Finans & Procurement                           NaN
# 1                        Entreprenad                           NaN
# 2                        Entreprenad                           NaN
# 3       TUI Customer Facing Services                           NaN
# 4    MO Finland Finance & Governance               SE IT Fusion AM
# ..                               ...                           ...
# 117             Finans & Procurement                           NaN
# 118               Business Platforms                           NaN
# 119            Digital Collaboration     SE IT 3rd Power Solutions
# 120             Finans & Procurement                           NaN
# 121               Business Platforms  SE IT Fusion TA & Deployment
#
#                Supportgrupp (2nd)                         Grupp
# 0        SE IT Fusion Procurement      SE IT Fusion Procurement
# 1                             NaN                           NaN
# 2                   SE IT ACC SWE                 SE IT ACC SWE
# 3                             NaN                           NaN
# 4                       FI Fusion                     FI Fusion
# ..                            ...                           ...
# 117     2nd MS SQL-Infrastructure     2nd MS SQL-Infrastructure
# 118   SE IT 3rd VSAA - Decerno AB   SE IT 3rd VSAA - Decerno AB
# 119     SE IT 3rd Power Solutions     SE IT 3rd Power Solutions
# 120                  SE IT RPA AM                  SE IT RPA AM
# 121  SE IT Fusion TA & Deployment  SE IT Fusion TA & Deployment
#
# [122 rows x 7 columns]

# %%
df = pd.merge(services, teammembers, on='Grupp', how='inner')
df
# Out:
#                                                 Namn  \
# 0    Credit Safe - supplier import and credit report
# 1    Credit Safe - supplier import and credit report
# 2    Credit Safe - supplier import and credit report
# 3    Credit Safe - supplier import and credit report
# 4    Credit Safe - supplier import and credit report
# ..                                               ...
# 721                                          Hjärnan
# 722                                           RPA AM
# 723                                           RPA AM
# 724                                           RPA AM
# 725                                           RPA AM
#
#                            Ägare                      Ansvarig  \
# 0    Jessica Axelsson (SE343575)  Alexander Janving (SE327069)
# 1    Jessica Axelsson (SE343575)  Alexander Janving (SE327069)
# 2    Jessica Axelsson (SE343575)  Alexander Janving (SE327069)
# 3    Jessica Axelsson (SE343575)  Alexander Janving (SE327069)
# 4    Jessica Axelsson (SE343575)  Alexander Janving (SE327069)
# ..                           ...                           ...
# 721   Mikael Ahlqvist (SE149184)   Krister Normark (SE340049C)
# 722  Jessica Axelsson (SE343575)   Brindaduti Maiti (SE342434)
# 723  Jessica Axelsson (SE343575)   Brindaduti Maiti (SE342434)
# 724  Jessica Axelsson (SE343575)   Brindaduti Maiti (SE342434)
# 725  Jessica Axelsson (SE343575)   Brindaduti Maiti (SE342434)
#
#        Förvaltningsobjekt Supportgrupp (3rd)           Supportgrupp (2nd)  \
# 0    Finans & Procurement                NaN     SE IT Fusion Procurement
# 1    Finans & Procurement                NaN     SE IT Fusion Procurement
# 2    Finans & Procurement                NaN     SE IT Fusion Procurement
# 3    Finans & Procurement                NaN     SE IT Fusion Procurement
# 4    Finans & Procurement                NaN     SE IT Fusion Procurement
# ..                    ...                ...                          ...
# 721    Business Platforms                NaN  SE IT 3rd VSAA - Decerno AB
# 722  Finans & Procurement                NaN                 SE IT RPA AM
# 723  Finans & Procurement                NaN                 SE IT RPA AM
# 724  Finans & Procurement                NaN                 SE IT RPA AM
# 725  Finans & Procurement                NaN                 SE IT RPA AM
#
#                            Grupp                                 E-post
# 0       SE IT Fusion Procurement               bhabani.sahoo@skanska.se
# 1       SE IT Fusion Procurement                jonas.edholm@skanska.se
# 2       SE IT Fusion Procurement            dayanidhi.mishra@skanska.se
# 3       SE IT Fusion Procurement  kishore.kadikalasadanandam@skanska.se
# 4       SE IT Fusion Procurement                aniket.patil@skanska.se
# ..                           ...                                    ...
# 721  SE IT 3rd VSAA - Decerno AB            mustafa.elomeiri@skanska.se
# 722                 SE IT RPA AM                brinda.maiti@skanska.se
# 723                 SE IT RPA AM                swati.jadhav@skanska.se
# 724                 SE IT RPA AM                deepak.patil@skanska.se
# 725                 SE IT RPA AM             linus.ljungberg@skanska.se
#
# [726 rows x 8 columns]

# %%
sample = services["Namn"].drop_duplicates() #.sample(10)
dataview = df[df['Namn'].isin(sample)]
dataview = dataview.drop(['Ägare', 'Ansvarig','Förvaltningsobjekt', 'Supportgrupp (3rd)', 'Supportgrupp (2nd)'], axis=1)
dataview = dataview.rename(columns={"Namn": "Service", "Grupp": "Team", "E-post": "E-post"})
dataview
# Out:
#                                              Service  \
# 0    Credit Safe - supplier import and credit report
# 1    Credit Safe - supplier import and credit report
# 2    Credit Safe - supplier import and credit report
# 3    Credit Safe - supplier import and credit report
# 4    Credit Safe - supplier import and credit report
# ..                                               ...
# 721                                          Hjärnan
# 722                                           RPA AM
# 723                                           RPA AM
# 724                                           RPA AM
# 725                                           RPA AM
#
#                             Team                                 E-post
# 0       SE IT Fusion Procurement               bhabani.sahoo@skanska.se
# 1       SE IT Fusion Procurement                jonas.edholm@skanska.se
# 2       SE IT Fusion Procurement            dayanidhi.mishra@skanska.se
# 3       SE IT Fusion Procurement  kishore.kadikalasadanandam@skanska.se
# 4       SE IT Fusion Procurement                aniket.patil@skanska.se
# ..                           ...                                    ...
# 721  SE IT 3rd VSAA - Decerno AB            mustafa.elomeiri@skanska.se
# 722                 SE IT RPA AM                brinda.maiti@skanska.se
# 723                 SE IT RPA AM                swati.jadhav@skanska.se
# 724                 SE IT RPA AM                deepak.patil@skanska.se
# 725                 SE IT RPA AM             linus.ljungberg@skanska.se
#
# [726 rows x 3 columns]

# %%
# Visualize teams and members
teams = dataview.drop(['Service'], axis=1)
teams = teams.drop_duplicates()
for i, row in teams.iterrows():
    antal = teams[teams["E-post"] ==teams.at[i,"E-post"]]["E-post"].count()
    teams.at[i,'Amount'] = 1/antal
teams
# Out:
#                             Team                                 E-post  \
# 0       SE IT Fusion Procurement               bhabani.sahoo@skanska.se
# 1       SE IT Fusion Procurement                jonas.edholm@skanska.se
# 2       SE IT Fusion Procurement            dayanidhi.mishra@skanska.se
# 3       SE IT Fusion Procurement  kishore.kadikalasadanandam@skanska.se
# 4       SE IT Fusion Procurement                aniket.patil@skanska.se
# ..                           ...                                    ...
# 721  SE IT 3rd VSAA - Decerno AB            mustafa.elomeiri@skanska.se
# 722                 SE IT RPA AM                brinda.maiti@skanska.se
# 723                 SE IT RPA AM                swati.jadhav@skanska.se
# 724                 SE IT RPA AM                deepak.patil@skanska.se
# 725                 SE IT RPA AM             linus.ljungberg@skanska.se
#
#        Amount
# 0    0.500000
# 1    0.333333
# 2    0.500000
# 3    0.333333
# 4    0.500000
# ..        ...
# 721  0.500000
# 722  1.000000
# 723  1.000000
# 724  1.000000
# 725  0.500000
#
# [364 rows x 3 columns]

# %%
import networkx as nx
import numpy as np
from pyvis.network import Network

team_members = pd.DataFrame(
    {
        "source": teams["E-post"].tolist(),
        "target": teams["Team"].tolist(),
        "weight": teams["Amount"].tolist()
    }
)
G_team_members = nx.from_pandas_edgelist(team_members, edge_attr=True)
net = Network(notebook=True)
for source in team_members['source'].unique():
    net.add_node(source, label=source)
for target in team_members['target'].unique():
    net.add_node(target, label=target, color='red')
for index, row in team_members.iterrows():
    net.add_edge(row['source'], row['target'], value=row['weight']/3, color='gray')
net.show("team_members.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# team_members.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="team_members.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
with open("team_members.html", "r") as file:
    html_data = file.read()

start = html_data.find("nodes =")
end = html_data.find("nodeColors = {};")
javascript_data = html_data[start:end].strip()
javascript_data = javascript_data.replace("nodes = ", "team_nodes = ")
javascript_data = javascript_data.replace("edges = ", "team_edges = ")
file = open("data/team_members.js", "wt") #(r)ead, (a)ppend, (w)rite, create(x) (t)ext/(b)inary
file.write(javascript_data)
file.close()

import os
os.remove("team_members.html")
