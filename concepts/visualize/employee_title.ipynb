# %% [markdown]
# # Visualize Employees and their title

# %%
import pandas as pd

# %%
Users = pd.read_excel("data/data.xlsx", 'Users')
Users
# Out:
#          Username                Name                      Title  \
# 0         BrandtN      Brandt, Niklas                 IT-Partner
# 1     BjorklundMi   Björklund, Mikael              Funktionschef
# 2         BemingC     Beming, Cecilia           Kategoriansvarig
# 3      AnderssAsa      Bergström, Åsa        Marknadskoordinator
# 4       AhlqvistM    Ahlqvist, Mikael                  Gruppchef
# ...           ...                 ...                        ...
# 6688    HellgrenM    Hellgren, Magnus               Bergarbetare
# 6689    AronssonC  Aronsson, Christer  Väg & Anläggningsarbetare
# 6690     SetermoC       Setermo, Carl                Träarbetare
# 6691       OcskoT       Ocsko, Tobias            Projektingenjör
# 6692         ElmJ          Elm, Julia        Produktionsingenjör
#
#                              Email                                     Group
# 0         niklas.brandt@skanska.se                 36704 Regional IT Support
# 1      mikael.bjorklund@skanska.se                 36701 Common Services HOF
# 2        cecilia.beming@skanska.se                      31320 Inköp Indirekt
# 3         asa.bergstrom@skanska.se                   41800 SIS OpC Norr Stab
# 4       mikael.ahlqvist@skanska.se                  36703 Business Platforms
# ...                            ...                                       ...
# 6688    magnus.hellgren@skanska.se  41223 SIS Prod Losshållning Norr och Öst
# 6689  christer.aronsson@skanska.se  71660 VoA Norr DC Västernorrl/Jämtl Stab
# 6690       carl.setermo@skanska.se          71440 VoA MSv DC Bergslagen Stab
# 6691       tobias.ocsko@skanska.se       52530 Hus Sthlm Syd Distrikt 3 Stab
# 6692          julia.elm@skanska.se             53230 Hus Sthlm Nord DC6 Stab
#
# [6693 rows x 5 columns]

# %%
groups = pd.read_excel("data/data.xlsx", 'Groups', dtype="string")
groups[['code','Display Name']] = groups["Name"].str.split(" ", n=1, expand=True)
groups.drop(["code"],axis=1, inplace=True)
groups
# Out:
#                               Name                     Boss Email  \
# 0            36803 HR and Learning    pernilla.widlund@skanska.se
# 1         36703 Business Platforms     mikael.ahlqvist@skanska.se
# 2   36806 Customer facing services   malin.hormanseder@skanska.se
# 3            36605 Data Foundation       cecilia.backa@skanska.se
# 4        36706 Digital arbetsplats  kristoffer.winberg@skanska.se
# 5      36705 Digital Collaboration       karam.chammas@skanska.se
# 6                36802 Entreprenad          linn.areno@skanska.se
# 7    36804 Finance and Procurement    jessica.axelsson@skanska.se
# 8            36702 IT Service Desk     goran.liljeberg@skanska.se
# 9        36704 Regional IT Support     joakim.vahatalo@skanska.se
# 10                            <NA>                           <NA>
#
#              Boss Name              Display Name
# 0     Pernilla Widlund           HR and Learning
# 1      Mikael Ahlqvist        Business Platforms
# 2    Malin Hörmanseder  Customer facing services
# 3        Cecilia Backa           Data Foundation
# 4   Kristoffer Winberg       Digital arbetsplats
# 5        Karam Chammas     Digital Collaboration
# 6           Linn Areno               Entreprenad
# 7     Jessica Axelsson   Finance and Procurement
# 8      Göran Liljeberg           IT Service Desk
# 9      Joakim Vähätalo       Regional IT Support
# 10      Hans Malmström                      <NA>

# %%
dataview = Users[Users['Group'].isin(groups["Name"])]
dataview = dataview.drop(['Username', 'Email','Group'], axis=1)
dataview
# Out:
#                     Name                      Title
# 0         Brandt, Niklas                 IT-Partner
# 4       Ahlqvist, Mikael                  Gruppchef
# 11       Forsberg, Jimmy           IT Tjänsteledare
# 109   Strömstedt, Ludwig  IT Applikationsspecialist
# 122     Ljungberg, Linus  IT Applikationsspecialist
# ...                  ...                        ...
# 6654     Espino, Marione           System Developer
# 6660   Santra, Snehashis     Application Specialist
# 6669     Stevall, Robert           System Developer
# 6670   Ramesh, Nireeksha           System Developer
# 6671     Carlberg, Jonas           System Developer
#
# [256 rows x 2 columns]

# %%
dataview["Name"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 256 entries, 0 to 6671
# Series name: Name
# Non-Null Count  Dtype
# --------------  -----
# 256 non-null    object
# dtypes: object(1)
# memory usage: 4.0+ KB

# %%
import networkx as nx
import numpy as np
from pyvis.network import Network

visualizationdata = pd.DataFrame(
    {
        "source": dataview["Name"].tolist(),
        "target": dataview["Title"].tolist(),
        "weight": 0
    }
)
G_team_members = nx.from_pandas_edgelist(visualizationdata, edge_attr=True)
net = Network(notebook=True)
for source in visualizationdata['source'].unique():
    net.add_node(source, label=source)
for target in visualizationdata['target'].unique():
    net.add_node(target, label=target, color='red')
for index, row in visualizationdata.iterrows():
    net.add_edge(row['source'], row['target'], value=row['weight']/3, color='gray')
net.show("employee_title.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# employee_title.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="employee_title.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
with open("employee_title.html", "r") as file:
    html_data = file.read()

start = html_data.find("nodes =")
end = html_data.find("nodeColors = {};")
javascript_data = html_data[start:end].strip()
javascript_data = javascript_data.replace("nodes = ", "title_nodes = ")
javascript_data = javascript_data.replace("edges = ", "title_edges = ")
print(javascript_data)
file = open("data/employee_title.js", "wt") #(r)ead, (a)ppend, (w)rite, create(x) (t)ext/(b)inary
file.write(javascript_data)
file.close()

import os
os.remove("employee_title.html")
# Out:
# title_nodes = new vis.DataSet([{"color": "#97c2fc", "id": "Brandt, Niklas", "label": "Brandt, Niklas", "shape": "dot"}, {"color": "#97c2fc", "id": "Ahlqvist, Mikael", "label": "Ahlqvist, Mikael", "shape": "dot"}, {"color": "#97c2fc", "id": "Forsberg, Jimmy", "label": "Forsberg, Jimmy", "shape": "dot"}, {"color": "#97c2fc", "id": "Str\u00f6mstedt, Ludwig", "label": "Str\u00f6mstedt, Ludwig", "shape": "dot"}, {"color": "#97c2fc", "id": "Ljungberg, Linus", "label": "Ljungberg, Linus", "shape": "dot"}, {"color": "#97c2fc", "id": "Haglund, Marie", "label": "Haglund, Marie", "shape": "dot"}, {"color": "#97c2fc", "id": "Brattl\u00f6w, Jonna", "label": "Brattl\u00f6w, Jonna", "shape": "dot"}, {"color": "#97c2fc", "id": "Widlund, Pernilla", "label": "Widlund, Pernilla", "shape": "dot"}, {"color": "#97c2fc", "id": "Jansson, Torbj\u00f6rn", "label": "Jansson, Torbj\u00f6rn", "shape": "dot"}, {"color": "#97c2fc", "id": "Ljungberg, Henrik", "label": "Ljungberg, Henrik", "shape": "dot"}, {"color": "#97c2fc", "id": "Ferm, Anders", "label": "Ferm, Anders", "shape": "dot"}, {"color": "#97c2fc", "id": "Jonsson, Eva-Christine", "label": "Jonsson, Eva-Christine", "shape": "dot"}, {"color": "#97c2fc", "id": "Johansson, Ronnie", "label": "Johansson, Ronnie", "shape": "dot"}, {"color": "#97c2fc", "id": "Malmqvist, Daniel", "label": "Malmqvist, Daniel", "shape": "dot"}, {"color": "#97c2fc", "id": "Welin, Margareta", "label": "Welin, Margareta", "shape": "dot"}, {"color": "#97c2fc", "id": "Fagerberg, Per", "label": "Fagerberg, Per", "shape": "dot"}, {"color": "#97c2fc", "id": "Reijs, Helen", "label": "Reijs, Helen", "shape": "dot"}, {"color": "#97c2fc", "id": "Van der Stad, Erik", "label": "Van der Stad, Erik", "shape": "dot"}, {"color": "#97c2fc", "id": "Lundin, Jan (LundiJ)", "label": "Lundin, Jan (LundiJ)", "shape": "dot"}, {"color": "#97c2fc", "id": "S\u00f6derqvist, Niklas", "label": "S\u00f6derqvist, Niklas", "shape": "dot"}, {"color": "#97c2fc", "id": "Walambe, Vaishakh", "label": "Walambe, Vaishakh", "shape": "dot"}, {"color": "#97c2fc", "id": "Jensen, Daniel", "label": "Jensen, Daniel", "shape": "dot"}, {"color": "#97c2fc", "id": "Areno, Linn", "label": "Areno, Linn", "shape": "dot"}, {"color": "#97c2fc", "id": "Roy, Shaibal", "label": "Roy, Shaibal", "shape": "dot"}, {"color": "#97c2fc", "id": "R\u00e5stedt, Jonna", "label": "R\u00e5stedt, Jonna", "shape": "dot"}, {"color": "#97c2fc", "id": "Axelsson, Jessica", "label": "Axelsson, Jessica", "shape": "dot"}, {"color": "#97c2fc", "id": "Khatibnia, Payam", "label": "Khatibnia, Payam", "shape": "dot"}, {"color": "#97c2fc", "id": "Fryxell, Carl-Johan", "label": "Fryxell, Carl-Johan", "shape": "dot"}, {"color": "#97c2fc", "id": "Kankim\u00e4ki, Petri", "label": "Kankim\u00e4ki, Petri", "shape": "dot"}, {"color": "#97c2fc", "id": "Janving, Alexander", "label": "Janving, Alexander", "shape": "dot"}, {"color": "#97c2fc", "id": "Mahesh, Chintada", "label": "Mahesh, Chintada", "shape": "dot"}, {"color": "#97c2fc", "id": "Shashin, Pande", "label": "Shashin, Pande", "shape": "dot"}, {"color": "#97c2fc", "id": "Johansson, Andreas", "label": "Johansson, Andreas", "shape": "dot"}, {"color": "#97c2fc", "id": "Wenster, Helene (WensterHe)", "label": "Wenster, Helene (WensterHe)", "shape": "dot"}, {"color": "#97c2fc", "id": "Lagerstr\u00f6m, Robin", "label": "Lagerstr\u00f6m, Robin", "shape": "dot"}, {"color": "#97c2fc", "id": "Mironov, Anatoly", "label": "Mironov, Anatoly", "shape": "dot"}, {"color": "#97c2fc", "id": "Lund, Joel", "label": "Lund, Joel", "shape": "dot"}, {"color": "#97c2fc", "id": "Katikala Sadanandam, Kishore", "label": "Katikala Sadanandam, Kishore", "shape": "dot"}, {"color": "#97c2fc", "id": "Maiti, Brinda", "label": "Maiti, Brinda", "shape": "dot"}, {"color": "#97c2fc", "id": "Backa, Cecilia", "label": "Backa, Cecilia", "shape": "dot"}, {"color": "#97c2fc", "id": "Lundberg, Anette", "label": "Lundberg, Anette", "shape": "dot"}, {"color": "#97c2fc", "id": "Edholm, Jonas", "label": "Edholm,  ...
#                   title_edges = new vis.DataSet([{"color": "gray", "from": "Brandt, Niklas", "to": "IT-Partner", "value": 0.0}, {"color": "gray", "from": "Ahlqvist, Mikael", "to": "Gruppchef", "value": 0.0}, {"color": "gray", "from": "Forsberg, Jimmy", "to": "IT Tj\u00e4nsteledare", "value": 0.0}, {"color": "gray", "from": "Str\u00f6mstedt, Ludwig", "to": "IT Applikationsspecialist", "value": 0.0}, {"color": "gray", "from": "Ljungberg, Linus", "to": "IT Applikationsspecialist", "value": 0.0}, {"color": "gray", "from": "Haglund, Marie", "to": "IT Applikationsspecialist", "value": 0.0}, {"color": "gray", "from": "Brattl\u00f6w, Jonna", "to": "Utvecklingsledare", "value": 0.0}, {"color": "gray", "from": "Widlund, Pernilla", "to": "Gruppchef", "value": 0.0}, {"color": "gray", "from": "Jansson, Torbj\u00f6rn", "to": "Utvecklingsledare", "value": 0.0}, {"color": "gray", "from": "Ljungberg, Henrik", "to": "Utvecklingsledare", "value": 0.0}, {"color": "gray", "from": "Ferm, Anders", "to": "IT Tj\u00e4nsteledare", "value": 0.0}, {"color": "gray", "from": "Jonsson, Eva-Christine", "to": "IT Applikationsspecialist", "value": 0.0}, {"color": "gray", "from": "Johansson, Ronnie", "to": "IT Applikationsspecialist", "value": 0.0}, {"color": "gray", "from": "Malmqvist, Daniel", "to": "IT-Partner", "value": 0.0}, {"color": "gray", "from": "Welin, Margareta", "to": "IT Applikationsspecialist", "value": 0.0}, {"color": "gray", "from": "Fagerberg, Per", "to": "IT Applikationsspecialist", "value": 0.0}, {"color": "gray", "from": "Reijs, Helen", "to": "IT Applikationsspecialist", "value": 0.0}, {"color": "gray", "from": "Van der Stad, Erik", "to": "IT Tj\u00e4nsteledare", "value": 0.0}, {"color": "gray", "from": "Lundin, Jan (LundiJ)", "to": "System Developer", "value": 0.0}, {"color": "gray", "from": "S\u00f6derqvist, Niklas", "to": "System Developer", "value": 0.0}, {"color": "gray", "from": "Walambe, Vaishakh", "to": "System Administrator", "value": 0.0}, {"color": "gray", "from": "Jensen, Daniel", "to": "IT Arkitekt", "value": 0.0}, {"color": "gray", "from": "Areno, Linn", "to": "Gruppchef", "value": 0.0}, {"color": "gray", "from": "Roy, Shaibal", "to": "Application Specialist", "value": 0.0}, {"color": "gray", "from": "R\u00e5stedt, Jonna", "to": "IT Tj\u00e4nsteledare", "value": 0.0}, {"color": "gray", "from": "Axelsson, Jessica", "to": "Gruppchef", "value": 0.0}, {"color": "gray", "from": "Khatibnia, Payam", "to": "IT Service Manager", "value": 0.0}, {"color": "gray", "from": "Fryxell, Carl-Johan", "to": "IT Tj\u00e4nsteledare", "value": 0.0}, {"color": "gray", "from": "Kankim\u00e4ki, Petri", "to": "IT Service Desk Agent", "value": 0.0}, {"color": "gray", "from": "Janving, Alexander", "to": "IT Applikationsspecialist", "value": 0.0}, {"color": "gray", "from": "Mahesh, Chintada", "to": "System Developer", "value": 0.0}, {"color": "gray", "from": "Shashin, Pande", "to": "System Developer", "value": 0.0}, {"color": "gray", "from": "Johansson, Andreas", "to": "System Developer", "value": 0.0}, {"color": "gray", "from": "Wenster, Helene (WensterHe)", "to": "Application Specialist", "value": 0.0}, {"color": "gray", "from": "Lagerstr\u00f6m, Robin", "to": "IT Applikationsspecialist", "value": 0.0}, {"color": "gray", "from": "Mironov, Anatoly", "to": "IT Arkitekt", "value": 0.0}, {"color": "gray", "from": "Lund, Joel", "to": "Administrat\u00f6r", "value": 0.0}, {"color": "gray", "from": "Katikala Sadanandam, Kishore", "to": "Application Specialist", "value": 0.0}, {"color": "gray", "from": "Maiti, Brinda", "to": "IT Tj\u00e4nsteledare", "value": 0.0}, {"color": "gray", "from": "Backa, Cecilia", "to": "Gruppchef", "value": 0.0}, {"color": "gray", "from": "Lundberg, Anette", "to": "IT Applikationsspecialist", "value": 0.0}, {"color": "gray", "from": "Edholm, Jonas", "to": "IT Applikationsspecialist", "value": 0.0}, {"color": "gray", "from": "Lundblad, Bengt", "to": "IT Arkitekt", "value": 0.0}, {"color": "gray", "from": "Behring, Rikard", "to": "Utvec ...
