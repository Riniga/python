# %% [markdown]
# # Visualize Employees and their title

# %%
import pandas as pd

# %%
Users = pd.read_excel("data/data.xlsx", 'Users')
Users
# Out:
#           Username                     Name                      Title  \
# 0     ZetterstromP         Zetterström, Pia          Web Administrator
# 1        LarssonEv  Larsson, Eva (Värmland)            Projektingenjör
# 2       FagerbergP           Fagerberg, Per  IT Applikationsspecialist
# 3        DolietisU         Dolietis, Ulrika              Funktionschef
# 4           WelinM         Welin, Margareta  IT Applikationsspecialist
# ...            ...                      ...                        ...
# 6651     HillgrenE           Hillgren, Elin            Produktionschef
# 6652       SchutzS        Schütz, Stephanie          Träarbetarlärling
# 6653     BengtzenT         Bengtsén, Tobias              HR Specialist
# 6654   KetolainenJ         Ketolainen, Jari            Produktionschef
# 6655     JanssonvI          Jansson, Viktor             Betongarbetare
#
#                             Email        Phone  \
# 0      pia.zetterstrom@skanska.se  46104493336
# 1        Eva.K.Larsson@Skanska.se  46104492080
# 2        Per.Fagerberg@Skanska.se  46104484119
# 3      Ulrika.Dolietis@Skanska.se  46104496883
# 4      margareta.welin@skanska.se    104484391
# ...                           ...          ...
# 6651     elin.hillgren@skanska.se  46104482001
# 6652  stephanie.schutz@skanska.se  46104482002
# 6653   tobias.bengtsen@skanska.se  46104499395
# 6654   jari.ketolainen@skanska.se  46104492195
# 6655    viktor.jansson@skanska.se  46104492194
#
#                                          Group  \
# 0         21176 Digital Communication Channels
# 1                                     Hus Väst
# 2               36806 Customer facing services
# 3                            31001 Håll nollan
# 4               36806 Customer facing services
# ...                                        ...
# 6651              41150 SIS PC Entrp Fräs Stab
# 6652             52170 Hus Sthlm Nord DC3 Stab
# 6653  30355 Specialister och Systemförvaltning
# 6654          42780 Tillv PC Albyberg SIS Stab
# 6655        71330 VoA Sthlm DC Anläggning Stab
#
#                                    Office
# 0       Stockholm - Huvudkontor Lindhagen
# 1           Karlstad - Kontor Våxnäsgatan
# 2          Göteborg Regionkontor Citygate
# 3          Göteborg Regionkontor Citygate
# 4          Göteborg Regionkontor Citygate
# ...                                   ...
# 6651                       Gävle - Kontor
# 6652  Övriga - Med växlande arbetsplatser
# 6653    Stockholm - Huvudkontor Lindhagen
# 6654          Österhaninge Kross Albyberg
# 6655  Övriga - Med växlande arbetsplatser
#
# [6656 rows x 7 columns]

# %%
groups = pd.read_excel("data/data.xlsx", 'Groups', dtype="string")
groups[['code','Display Name']] = groups["Name"].str.split(" ", n=1, expand=True)
groups.drop(["code"],axis=1, inplace=True)
groups
# Out:
#                                  Name                     Boss Email  \
# 0               36803 HR and Learning    pernilla.widlund@skanska.se
# 1            36703 Business Platforms     mikael.ahlqvist@skanska.se
# 2      36806 Customer facing services   malin.hormanseder@skanska.se
# 3               36605 Data Foundation       cecilia.backa@skanska.se
# 4           36706 Digital arbetsplats  kristoffer.winberg@skanska.se
# 5         36705 Digital Collaboration       karam.chammas@skanska.se
# 6                   36802 Entreprenad          linn.areno@skanska.se
# 7       36804 Finance and Procurement    jessica.axelsson@skanska.se
# 8               36702 IT Service Desk     goran.liljeberg@skanska.se
# 9           36704 Regional IT Support     joakim.vahatalo@skanska.se
# 10  36606 Architecture and Governance      hans.malmstrom@skanska.se
# 11        36805 Leveranskoordinatorer    pernilla.widlund@skanska.se
#
#              Boss Name                 Display Name
# 0     Pernilla Widlund              HR and Learning
# 1      Mikael Ahlqvist           Business Platforms
# 2    Malin Hörmanseder     Customer facing services
# 3        Cecilia Backa              Data Foundation
# 4   Kristoffer Winberg          Digital arbetsplats
# 5        Karam Chammas        Digital Collaboration
# 6           Linn Areno                  Entreprenad
# 7     Jessica Axelsson      Finance and Procurement
# 8      Göran Liljeberg              IT Service Desk
# 9      Joakim Vähätalo          Regional IT Support
# 10      Hans Malmström  Architecture and Governance
# 11   Widlund, Pernilla        Leveranskoordinatorer

# %%
dataview = Users[Users['Group'].isin(groups["Name"])]
dataview = dataview.drop(['Username', 'Email','Group'], axis=1)
dataview
# Out:
#                                     Name                      Title  \
# 2                         Fagerberg, Per  IT Applikationsspecialist
# 4                       Welin, Margareta  IT Applikationsspecialist
# 19                     Malmqvist, Daniel                 IT-Partner
# 176                    Johansson, Ronnie  IT Applikationsspecialist
# 260               Jonsson, Eva-Christine  IT Applikationsspecialist
# ...                                  ...                        ...
# 6278           Pullaguri, Manideep Yadav        IT Systemutvecklare
# 6280                        Lökholm, Åse           System Developer
# 6376                     Malmström, Hans                  Gruppchef
# 6529                   Shaik, Ahmed Vali                IT Arkitekt
# 6534  Mandarino Adornetto, Anna Carolina          IT-teknisk expert
#
#             Phone                               Office
# 2     46104484119       Göteborg Regionkontor Citygate
# 4       104484391       Göteborg Regionkontor Citygate
# 19    46104483125                 Malmö - Regionkontor
# 176     104484194       Göteborg Regionkontor Citygate
# 260     104484197       Göteborg Regionkontor Citygate
# ...           ...                                  ...
# 6278  46104492216    Stockholm - Huvudkontor Lindhagen
# 6280  46733314805  Övriga - Med växlande arbetsplatser
# 6376  46104493068    Stockholm - Huvudkontor Lindhagen
# 6529  46104492624    Stockholm - Huvudkontor Lindhagen
# 6534  46104494177                 Malmö - Regionkontor
#
# [92 rows x 4 columns]

# %%
dataview["Name"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 92 entries, 2 to 6534
# Series name: Name
# Non-Null Count  Dtype
# --------------  -----
# 92 non-null     object
# dtypes: object(1)
# memory usage: 1.4+ KB

# %%
import networkx as nx
import numpy as np
from pyvis.network import Network

visualizationdata = pd.DataFrame(
    {
        "source": dataview["Name"].tolist(),
        "target": dataview["Title"].tolist(),
        "weight": 0
    }
)
G_team_members = nx.from_pandas_edgelist(visualizationdata, edge_attr=True)
net = Network(notebook=True)
for source in visualizationdata['source'].unique():
    net.add_node(source, label=source)
for target in visualizationdata['target'].unique():
    net.add_node(target, label=target, color='red')
for index, row in visualizationdata.iterrows():
    net.add_edge(row['source'], row['target'], value=row['weight']/3, color='gray')
net.show("employee_title.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# employee_title.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="employee_title.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
with open("employee_title.html", "r") as file:
    html_data = file.read()

start = html_data.find("nodes =")
end = html_data.find("nodeColors = {};")
javascript_data = html_data[start:end].strip()
javascript_data = javascript_data.replace("nodes = ", "title_nodes = ")
javascript_data = javascript_data.replace("edges = ", "title_edges = ")
print(javascript_data)
file = open("data/employee_title.js", "wt") #(r)ead, (a)ppend, (w)rite, create(x) (t)ext/(b)inary
file.write(javascript_data)
file.close()

import os
os.remove("employee_title.html")
# Out:
# title_nodes = new vis.DataSet([{"color": "#97c2fc", "id": "Fagerberg, Per", "label": "Fagerberg, Per", "shape": "dot"}, {"color": "#97c2fc", "id": "Welin, Margareta", "label": "Welin, Margareta", "shape": "dot"}, {"color": "#97c2fc", "id": "Malmqvist, Daniel", "label": "Malmqvist, Daniel", "shape": "dot"}, {"color": "#97c2fc", "id": "Johansson, Ronnie", "label": "Johansson, Ronnie", "shape": "dot"}, {"color": "#97c2fc", "id": "Jonsson, Eva-Christine", "label": "Jonsson, Eva-Christine", "shape": "dot"}, {"color": "#97c2fc", "id": "\u00d6hlund, Annika", "label": "\u00d6hlund, Annika", "shape": "dot"}, {"color": "#97c2fc", "id": "Ferm, Anders", "label": "Ferm, Anders", "shape": "dot"}, {"color": "#97c2fc", "id": "Ljungberg, Henrik", "label": "Ljungberg, Henrik", "shape": "dot"}, {"color": "#97c2fc", "id": "Jansson, Torbj\u00f6rn", "label": "Jansson, Torbj\u00f6rn", "shape": "dot"}, {"color": "#97c2fc", "id": "Widlund, Pernilla", "label": "Widlund, Pernilla", "shape": "dot"}, {"color": "#97c2fc", "id": "Brattl\u00f6w, Jonna", "label": "Brattl\u00f6w, Jonna", "shape": "dot"}, {"color": "#97c2fc", "id": "Forsberg, Jimmy", "label": "Forsberg, Jimmy", "shape": "dot"}, {"color": "#97c2fc", "id": "Ahlqvist, Mikael", "label": "Ahlqvist, Mikael", "shape": "dot"}, {"color": "#97c2fc", "id": "Brandt, Niklas", "label": "Brandt, Niklas", "shape": "dot"}, {"color": "#97c2fc", "id": "Chammas, Karam", "label": "Chammas, Karam", "shape": "dot"}, {"color": "#97c2fc", "id": "Dackheden, Mathias", "label": "Dackheden, Mathias", "shape": "dot"}, {"color": "#97c2fc", "id": "Ekl\u00f6f, Tomas", "label": "Ekl\u00f6f, Tomas", "shape": "dot"}, {"color": "#97c2fc", "id": "H\u00f6rmanseder, Malin", "label": "H\u00f6rmanseder, Malin", "shape": "dot"}, {"color": "#97c2fc", "id": "Lundblad, Kristofer", "label": "Lundblad, Kristofer", "shape": "dot"}, {"color": "#97c2fc", "id": "Lundqvist, Veronica", "label": "Lundqvist, Veronica", "shape": "dot"}, {"color": "#97c2fc", "id": "Marmestedt, Lars", "label": "Marmestedt, Lars", "shape": "dot"}, {"color": "#97c2fc", "id": "M\u00f6ller, Ingvar", "label": "M\u00f6ller, Ingvar", "shape": "dot"}, {"color": "#97c2fc", "id": "Nilsson, Ing-Marie", "label": "Nilsson, Ing-Marie", "shape": "dot"}, {"color": "#97c2fc", "id": "Nisses-Gagn\u00e9r, Rickard", "label": "Nisses-Gagn\u00e9r, Rickard", "shape": "dot"}, {"color": "#97c2fc", "id": "Olsson, Calle", "label": "Olsson, Calle", "shape": "dot"}, {"color": "#97c2fc", "id": "Persson, Patrik", "label": "Persson, Patrik", "shape": "dot"}, {"color": "#97c2fc", "id": "F\u00e4gerlind, Thomas", "label": "F\u00e4gerlind, Thomas", "shape": "dot"}, {"color": "#97c2fc", "id": "Roos, Magdalena", "label": "Roos, Magdalena", "shape": "dot"}, {"color": "#97c2fc", "id": "Rylander, Daniel", "label": "Rylander, Daniel", "shape": "dot"}, {"color": "#97c2fc", "id": "Wiklund, Linda", "label": "Wiklund, Linda", "shape": "dot"}, {"color": "#97c2fc", "id": "Snickars, Henrik", "label": "Snickars, Henrik", "shape": "dot"}, {"color": "#97c2fc", "id": "Stenb\u00e4ck, Patrik", "label": "Stenb\u00e4ck, Patrik", "shape": "dot"}, {"color": "#97c2fc", "id": "V\u00e4h\u00e4talo, Joakim", "label": "V\u00e4h\u00e4talo, Joakim", "shape": "dot"}, {"color": "#97c2fc", "id": "Iivonen, Ari", "label": "Iivonen, Ari", "shape": "dot"}, {"color": "#97c2fc", "id": "Jeric, Branko", "label": "Jeric, Branko", "shape": "dot"}, {"color": "#97c2fc", "id": "Ojala, Virpi", "label": "Ojala, Virpi", "shape": "dot"}, {"color": "#97c2fc", "id": "Campo Martinez, Maria Jose (CampoM)", "label": "Campo Martinez, Maria Jose (CampoM)", "shape": "dot"}, {"color": "#97c2fc", "id": "Blomberg, Peter", "label": "Blomberg, Peter", "shape": "dot"}, {"color": "#97c2fc", "id": "Green, Robert", "label": "Green, Robert", "shape": "dot"}, {"color": "#97c2fc", "id": "Bengtsson, Jan (Stockholm)", "label": "Bengtsson, Jan (Stockholm)", "shape": "dot"}, {"color": "#97c2fc", "id": "Wahlberg, Ylva", "label": "Wahlberg, Ylva", "shape": "dot"}, {"color": "#97c2 ...
#                   title_edges = new vis.DataSet([{"color": "gray", "from": "Fagerberg, Per", "to": "IT Applikationsspecialist", "value": 0.0}, {"color": "gray", "from": "Welin, Margareta", "to": "IT Applikationsspecialist", "value": 0.0}, {"color": "gray", "from": "Malmqvist, Daniel", "to": "IT-Partner", "value": 0.0}, {"color": "gray", "from": "Johansson, Ronnie", "to": "IT Applikationsspecialist", "value": 0.0}, {"color": "gray", "from": "Jonsson, Eva-Christine", "to": "IT Applikationsspecialist", "value": 0.0}, {"color": "gray", "from": "\u00d6hlund, Annika", "to": "Koncernarkitekt", "value": 0.0}, {"color": "gray", "from": "Ferm, Anders", "to": "IT Tj\u00e4nsteledare", "value": 0.0}, {"color": "gray", "from": "Ljungberg, Henrik", "to": "Utvecklingsledare", "value": 0.0}, {"color": "gray", "from": "Jansson, Torbj\u00f6rn", "to": "Utvecklingsledare", "value": 0.0}, {"color": "gray", "from": "Widlund, Pernilla", "to": "Gruppchef", "value": 0.0}, {"color": "gray", "from": "Brattl\u00f6w, Jonna", "to": "Utvecklingsledare", "value": 0.0}, {"color": "gray", "from": "Forsberg, Jimmy", "to": "IT Tj\u00e4nsteledare", "value": 0.0}, {"color": "gray", "from": "Ahlqvist, Mikael", "to": "Gruppchef", "value": 0.0}, {"color": "gray", "from": "Brandt, Niklas", "to": "IT-Partner", "value": 0.0}, {"color": "gray", "from": "Chammas, Karam", "to": "Gruppchef", "value": 0.0}, {"color": "gray", "from": "Dackheden, Mathias", "to": "IT Tj\u00e4nsteledare", "value": 0.0}, {"color": "gray", "from": "Ekl\u00f6f, Tomas", "to": "IT Tj\u00e4nsteledare", "value": 0.0}, {"color": "gray", "from": "H\u00f6rmanseder, Malin", "to": "Gruppchef", "value": 0.0}, {"color": "gray", "from": "Lundblad, Kristofer", "to": "IT-Partner", "value": 0.0}, {"color": "gray", "from": "Lundqvist, Veronica", "to": "IT Tj\u00e4nsteledare", "value": 0.0}, {"color": "gray", "from": "Marmestedt, Lars", "to": "IT Tj\u00e4nsteledare", "value": 0.0}, {"color": "gray", "from": "M\u00f6ller, Ingvar", "to": "IT-Partner, Huvudoperat\u00f6r", "value": 0.0}, {"color": "gray", "from": "Nilsson, Ing-Marie", "to": "IT Service Manager", "value": 0.0}, {"color": "gray", "from": "Nisses-Gagn\u00e9r, Rickard", "to": "IT-Leveranskoordinator", "value": 0.0}, {"color": "gray", "from": "Olsson, Calle", "to": "IT-Partner", "value": 0.0}, {"color": "gray", "from": "Persson, Patrik", "to": "IT-Partner", "value": 0.0}, {"color": "gray", "from": "F\u00e4gerlind, Thomas", "to": "IT Tj\u00e4nsteledare", "value": 0.0}, {"color": "gray", "from": "Roos, Magdalena", "to": "IT Service Desk Agent", "value": 0.0}, {"color": "gray", "from": "Rylander, Daniel", "to": "IT-Partner", "value": 0.0}, {"color": "gray", "from": "Wiklund, Linda", "to": "Application Specialist", "value": 0.0}, {"color": "gray", "from": "Snickars, Henrik", "to": "IT Service Desk Agent", "value": 0.0}, {"color": "gray", "from": "Stenb\u00e4ck, Patrik", "to": "IT Tj\u00e4nsteledare", "value": 0.0}, {"color": "gray", "from": "V\u00e4h\u00e4talo, Joakim", "to": "Gruppchef", "value": 0.0}, {"color": "gray", "from": "Iivonen, Ari", "to": "IT Service Desk Agent", "value": 0.0}, {"color": "gray", "from": "Jeric, Branko", "to": "IT Systemutvecklare", "value": 0.0}, {"color": "gray", "from": "Ojala, Virpi", "to": "IT Applikationsspecialist", "value": 0.0}, {"color": "gray", "from": "Campo Martinez, Maria Jose (CampoM)", "to": "IT Tj\u00e4nsteledare", "value": 0.0}, {"color": "gray", "from": "Blomberg, Peter", "to": "System Developer", "value": 0.0}, {"color": "gray", "from": "Green, Robert", "to": "IT Arkitekt", "value": 0.0}, {"color": "gray", "from": "Bengtsson, Jan (Stockholm)", "to": "System Developer", "value": 0.0}, {"color": "gray", "from": "Wahlberg, Ylva", "to": "IT Service Desk Agent", "value": 0.0}, {"color": "gray", "from": "Wid\u00e9n, Tomas", "to": "IT Systemutvecklare", "value": 0.0}, {"color": "gray", "from": "Keskitalo, Johan", "to": "IT Infrastrukturspecialist", "value": 0.0}, {"color": "gray", "from": "Wedberg, Marcus", "to": "IT Infr ...
