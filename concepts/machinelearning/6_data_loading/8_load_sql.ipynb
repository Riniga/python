# %% [markdown]
# # 8 Ladda data från SQL
# ## Requirements
# Requires installation of Postgresql  and that it could find pg_config in PATH
#
# Required modules
# - pip install sqlalchemy
# - pip install psycopg2

# %%
import pandas as pd
import sqlalchemy as sqls

# %%
conn = sql.create_engine("postgresql://rickard:hemlig@localhost/test")
df = pd.read_sql_table("sales", conn)
query = "SELECT * FROM Sales "
df = pd.read_sql_query(query, conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\NissesR\github\riniga\python\concepts\machinelearning\6_data_loading\8_load_sql.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/NissesR/github/riniga/python/concepts/machinelearning/6_data_loading/8_load_sql.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> conn = sql.create_engine("postgresql://rickard:hemlig@localhost/test")
#       <a href='vscode-notebook-cell:/c%3A/Users/NissesR/github/riniga/python/concepts/machinelearning/6_data_loading/8_load_sql.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> df = pd.read_sql_table("sales", conn)
#       <a href='vscode-notebook-cell:/c%3A/Users/NissesR/github/riniga/python/concepts/machinelearning/6_data_loading/8_load_sql.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> query = "SELECT * FROM Sales "
#
# NameError: name 'sql' is not defined
