# %% [markdown]
# ## Cleaning data
# Installera moduler
# pip install missingno
# pip install quilt
# quilt install ResidentialMario/missingno_data

# %%
import pandas as pd
import missingno as msno
df = pd.read_csv("data/housing.csv")

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
msno.bar(df)
# Out:
# <Axes: >

# %%
from quilt.data.ResidentialMario import missingno_data
