# %% [markdown]
# # 15 Validate Data with Schemas
#
# Required modules:
# - pip install pandas
# - pip install pandera

# %%
import pandas as pd
df = pd.read_csv("../data/housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
import pandera as pa
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\NissesR\github\riniga\python\concepts\machinelearning\12_data_cleaning\15_validate_data_with_schemas.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/NissesR/github/riniga/python/concepts/machinelearning/12_data_cleaning/15_validate_data_with_schemas.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> import pandera as pa
#
# File c:\Users\NissesR\AppData\Local\anaconda3\envs\msnotest\lib\site-packages\pandera\__init__.py:4
#       1 """A flexible and expressive pandas validation library."""
#       2 import platform
# ----> 4 import pandera.backends
#       5 from pandera import errors, external_config, typing
#       6 from pandera.accessors import pandas_accessor
#
# File c:\Users\NissesR\AppData\Local\anaconda3\envs\msnotest\lib\site-packages\pandera\backends\__init__.py:6
#       4 import pandera.backends.base.builtin_checks
#       5 import pandera.backends.base.builtin_hypotheses
# ----> 6 import pandera.backends.pandas
#
# File c:\Users\NissesR\AppData\Local\anaconda3\envs\msnotest\lib\site-packages\pandera\backends\pandas\__init__.py:12
#       9 from pandera.api.pandas.container import DataFrameSchema
#      10 from pandera.api.pandas.components import Column, Index, MultiIndex
# ---> 12 from pandera.backends.pandas import builtin_checks, builtin_hypotheses
#      13 from pandera.backends.pandas.checks import PandasCheckBackend
#      14 from pandera.backends.pandas.hypotheses import PandasHypothesisBackend
#
# File c:\Users\NissesR\AppData\Local\anaconda3\envs\msnotest\lib\site-packages\pandera\backends\pandas\builtin_hypotheses.py:14
#       6 from pandera.api.extensions import register_builtin_hypothesis
#       7 from pandera.backends.pandas.builtin_checks import PandasData
#      10 @register_builtin_hypothesis(
#      11     error="failed two sample ttest between '{sample1}' and '{sample2}'",
#      12     samples_kwtypes={"sample1": str, "sample2": str},
#      13 )
# ---> 14 def two_sample_ttest(
#      15     *samples: Tuple[PandasData, ...],
#      16     equal_var: bool = True,
#      17     nan_policy: str = "propagate",
#      18 ) -> Tuple[float, float]:
#      19     from scipy import stats  # pylint: disable=import-outside-toplevel
#      21     assert (
#      22         len(samples) == 2
#      23     ), "Expected two sample ttest data to contain exactly two samples"
#
# File c:\Users\NissesR\AppData\Local\anaconda3\envs\msnotest\lib\site-packages\pandera\api\extensions.py:88, in register_builtin_check(fn, strategy, _check_cls, **outer_kwargs)
#      78 if check_fn is None:  # pragma: no cover
#      79     raise BuiltinCheckRegistrationError(
#      80         f"Check '{name}' doesn't have a base check implementation. "
#      81         f"You need to create a stub method in the {_check_cls} class and "
#    (...)
#      85         "`pandera.backends.pandas.builtin_checks` modules as an example."
#      86     )
# ---> 88 check_fn.register(fn)  # type: ignore
#      90 return fn
#
# File c:\Users\NissesR\AppData\Local\anaconda3\envs\msnotest\lib\site-packages\multimethod\__init__.py:131, in multimethod.register(self, *args)
#     126 """Decorator for registering a function.
#     127
#     128 Optionally call with types to return a decorator for unannotated functions.
#     129 """
#     130 if len(args) == 1 and hasattr(args[0], '__annotations__'):
# --> 131     return overload.register(self, *args)
#     132 return lambda func: self.__setitem__(args, func) or func
#
# File c:\Users\NissesR\AppData\Local\anaconda3\envs\msnotest\lib\site-packages\multimethod\__init__.py:276, in overload.register(self, func)
#     274 def register(self, func: Callable) -> Callable:
#     275     """Decorator for registering a function."""
# --> 276     self.__init__(func)  # type: ignore
#     277     return self if self.__name__ == func.__name__ else func
#
# File c:\Users\NissesR\AppData\Local\anaconda3\envs\msnotest\lib\site-packages\multimethod\__init__.py:121, in multimethod.__init__(self, func)
#     119 def __init__(self, func: Callable):
#     120     try:
# --> 121         self[get_types(func)] = func
#     122     except NameError:
#     123         self.pending.add(func)
#
# File c:\Users\NissesR\AppData\Local\anaconda3\envs\msnotest\lib\site-packages\multimethod\__init__.py:151, in multimethod.__setitem__(self, types, func)
#     149 self.clean()
#     150 types = signature(types)
# --> 151 parents = types.parents = self.parents(types)
#     152 for key in self:
#     153     if types < key and (not parents or parents & key.parents):
#
# File c:\Users\NissesR\AppData\Local\anaconda3\envs\msnotest\lib\site-packages\multimethod\__init__.py:139, in multimethod.parents(self, types)
#     137 def parents(self, types: tuple) -> set:
#     138     """Find immediate parents of potential key."""
# --> 139     parents = {key for key in self if isinstance(key, signature) and key < types}
#     140     return parents - {ancestor for parent in parents for ancestor in parent.parents}
#
# File c:\Users\NissesR\AppData\Local\anaconda3\envs\msnotest\lib\site-packages\multimethod\__init__.py:139, in <setcomp>(.0)
#     137 def parents(self, types: tuple) -> set:
#     138     """Find immediate parents of potential key."""
# --> 139     parents = {key for key in self if isinstance(key, signature) and key < types}
#     140     return parents - {ancestor for parent in parents for ancestor in parent.parents}
#
# File c:\Users\NissesR\AppData\Local\anaconda3\envs\msnotest\lib\site-packages\multimethod\__init__.py:99, in signature.__lt__(self, other)
#      98 def __lt__(self, other) -> bool:
# ---> 99     return self != other and self <= other
#
# File c:\Users\NissesR\AppData\Local\anaconda3\envs\msnotest\lib\site-packages\multimethod\__init__.py:96, in signature.__le__(self, other)
#      95 def __le__(self, other) -> bool:
# ---> 96     return len(self) <= len(other) and all(map(issubclass, other, self))
#
# File c:\Users\NissesR\AppData\Local\anaconda3\envs\msnotest\lib\site-packages\multimethod\__init__.py:76, in subtype.__subclasscheck__(self, subclass)
#      71 if self.__origin__ is typing.Union:
#      72     return issubclass(subclass, self.__args__)
#      73 return (  # check args first to avoid a recursion error in ABCMeta
#      74     len(args) == len(self.__args__)
#      75     and issubclass(origin, self.__origin__)
# ---> 76     and all(map(issubclass, args, self.__args__))
#      77 )
#
# TypeError: issubclass() arg 1 must be a class

# %%
schema = pa.DataFrameSchema({"ocean_proximity": pa.Column(pa.String)})
schema.validate(df)

# %%
schema = pa.DataFrameSchema({"ocean_proximity": pa.Column(pa.String, pa.Check.isin(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND']))})
schema.validate(df)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
df["total_rooms"] = df["total_rooms"].astype("int64")
schema = pa.DataFrameSchema({"ocean_proximity": pa.Column(pa.String, pa.Check.isin(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'])),
                             "total_rooms": pa.Column(pa.Int),
                             "housing_median_age":pa.Column(pa.Float, pa.Check(lambda n: n is not None))})
schema.validate(df)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0          880           129.0
# 1        -122.22     37.86                21.0         7099          1106.0
# 2        -122.24     37.85                52.0         1467           190.0
# 3        -122.25     37.85                52.0         1274           235.0
# 4        -122.25     37.85                52.0         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0         1665           374.0
# 20636    -121.21     39.49                18.0          697           150.0
# 20637    -121.22     39.43                17.0         2254           485.0
# 20638    -121.32     39.43                18.0         1860           409.0
# 20639    -121.24     39.37                16.0         2785           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %% [markdown]
# ## Exaple of why to use this...

# %%
df_simple = pd.DataFrame({"percentages" : [.1,.3, 25.3, 4.1, .21,99]})

# Fix error before validation
df_simple.percentages[df_simple.percentages>1] /= 100


#schema = pa.DataFrameSchema({"percentages": pa.Column(pa.Float, pa.Check(lambda n: n <= 1))})
schema = pa.DataFrameSchema({"percentages": pa.Column(pa.Float, pa.Check.less_than_or_equal_to(1))})

schema.validate(df_simple)
# Out:
#    percentages
# 0        0.100
# 1        0.300
# 2        0.253
# 3        0.041
# 4        0.210
# 5        0.990
