# %% [markdown]
# # 14 Scaling and Binding Numerical Data data
#
# Required modules:
# - pip install pandas
# - pip install numpy
# - pip install missingno
# - pip install scipy
# - pip install scikit-learn

# %%
import pandas as pd
import numpy as np

file = "../data/nyc_yellow_taxi_trip_selection.csv" # Takes about xx seconds...
#file = "../data/nyc_yellow_taxi_trip_records_from_Jan_to_Aug_2023.csv" # Huge takes almost 3 minutes to load

df = pd.read_csv(file, parse_dates=["tpep_pickup_datetime", "tpep_dropoff_datetime"] )
#df = pd.read_csv(file, usecols=["VendorID","tpep_pickup_datetime","tpep_dropoff_datetime","passenger_count","trip_distance","RatecodeID","PULocationID","DOLocationID","tip_amount","total_amount"], parse_dates=["tpep_pickup_datetime", "tpep_dropoff_datetime"] )
df = df.replace("NaN", np.nan)
df["passenger_count_corrected"] = df["passenger_count"] 
df["passenger_count_corrected"].fillna(df["passenger_count"].median(), inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  VendorID tpep_pickup_datetime  \
# 0       9194462     9194462         2  2023-04-09 17:39:57
# 1      16987466    16987466         2  2023-01-26 14:47:44
# 2       6908899     6908899         2  2023-04-30 01:08:10
# 3       4617323     4617323         1  2023-05-19 17:10:40
# 4      14262454    14262454         2  2023-02-21 21:34:26
#
#   tpep_dropoff_datetime  passenger_count  trip_distance  RatecodeID  \
# 0   2023-04-09 18:13:31              2.0           9.81         1.0
# 1   2023-01-26 14:53:07              1.0           0.99         1.0
# 2   2023-04-30 01:20:46              2.0           2.85         1.0
# 3   2023-05-19 17:23:00              1.0           1.80         1.0
# 4   2023-02-21 21:38:01              1.0           1.23         1.0
#
#   store_and_fwd_flag  PULocationID  ...  extra  mta_tax  tip_amount  \
# 0                  N           132  ...    0.0      0.5        3.00
# 1                  N           170  ...    0.0      0.5        2.24
# 2                  N           114  ...    1.0      0.5        4.12
# 3                  N           229  ...    5.0      0.5        3.70
# 4                  N            48  ...    1.0      0.5        2.44
#
#    tolls_amount  improvement_surcharge  total_amount  congestion_surcharge  \
# 0           0.0                    1.0         51.25                   0.0
# 1           0.0                    1.0         13.44                   2.5
# 2           0.0                    1.0         24.72                   2.5
# 3           0.0                    1.0         22.30                   2.5
# 4           0.0                    1.0         14.64                   2.5
#
#    Airport_fee  airport_fee  passenger_count_corrected
# 0         1.75          NaN                        2.0
# 1          NaN          0.0                        1.0
# 2         0.00          NaN                        2.0
# 3         0.00          NaN                        1.0
# 4         0.00          NaN                        1.0
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Remove extreme values (outliers)

# %%
from scipy import stats
q_low = df["total_amount"].quantile(0.01)
q_hi  = df["total_amount"].quantile(0.9999)

df = df[(df["total_amount"] < q_hi) & (df["total_amount"] > q_low)]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 989697 entries, 0 to 999999
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Unnamed: 0.1               989697 non-null  int64
#  1   Unnamed: 0                 989697 non-null  int64
#  2   VendorID                   989697 non-null  int64
#  3   tpep_pickup_datetime       989697 non-null  datetime64[ns]
#  4   tpep_dropoff_datetime      989697 non-null  datetime64[ns]
#  5   passenger_count            962685 non-null  float64
#  6   trip_distance              989697 non-null  float64
#  7   RatecodeID                 962685 non-null  float64
#  8   store_and_fwd_flag         962685 non-null  object
#  9   PULocationID               989697 non-null  int64
#  10  DOLocationID               989697 non-null  int64
#  11  payment_type               989697 non-null  int64
#  12  fare_amount                989697 non-null  float64
#  13  extra                      989697 non-null  float64
#  14  mta_tax                    989697 non-null  float64
#  15  tip_amount                 989697 non-null  float64
#  16  tolls_amount               989697 non-null  float64
#  17  improvement_surcharge      989697 non-null  float64
#  18  total_amount               989697 non-null  float64
#  19  congestion_surcharge       962685 non-null  float64
#  20  Airport_fee                810787 non-null  float64
#  21  airport_fee                151898 non-null  float64
#  22  passenger_count_corrected  989697 non-null  float64
# dtypes: datetime64[ns](2), float64(14), int64(6), object(1)
# memory usage: 181.2+ MB

# %% [markdown]
# ## Min-Max Scaling with:
# $$x' = \frac{x - \text{min}(x)}{\text{max}(x)-\text{min}(x)}

# %%
df["total_amount_minmax"] = (df.total_amount-df.total_amount.min()) / (df.total_amount.max()-df.total_amount.min())
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  VendorID tpep_pickup_datetime  \
# 0       9194462     9194462         2  2023-04-09 17:39:57
# 1      16987466    16987466         2  2023-01-26 14:47:44
# 2       6908899     6908899         2  2023-04-30 01:08:10
# 3       4617323     4617323         1  2023-05-19 17:10:40
# 4      14262454    14262454         2  2023-02-21 21:34:26
#
#   tpep_dropoff_datetime  passenger_count  trip_distance  RatecodeID  \
# 0   2023-04-09 18:13:31              2.0           9.81         1.0
# 1   2023-01-26 14:53:07              1.0           0.99         1.0
# 2   2023-04-30 01:20:46              2.0           2.85         1.0
# 3   2023-05-19 17:23:00              1.0           1.80         1.0
# 4   2023-02-21 21:38:01              1.0           1.23         1.0
#
#   store_and_fwd_flag  PULocationID  ...  mta_tax  tip_amount  tolls_amount  \
# 0                  N           132  ...      0.5        3.00           0.0
# 1                  N           170  ...      0.5        2.24           0.0
# 2                  N           114  ...      0.5        4.12           0.0
# 3                  N           229  ...      0.5        3.70           0.0
# 4                  N            48  ...      0.5        2.44           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee  \
# 0                    1.0         51.25                   0.0         1.75
# 1                    1.0         13.44                   2.5          NaN
# 2                    1.0         24.72                   2.5         0.00
# 3                    1.0         22.30                   2.5         0.00
# 4                    1.0         14.64                   2.5         0.00
#
#    airport_fee  passenger_count_corrected  total_amount_minmax
# 0          NaN                        2.0             0.144661
# 1          0.0                        1.0             0.027639
# 2          NaN                        2.0             0.062550
# 3          NaN                        1.0             0.055060
# 4          NaN                        1.0             0.031353
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Z-Score with
# $$x' = \frac{x - \bar{x}}{\sigma}

# %%
df["total_amount_z"] =  (df.total_amount - df.total_amount.mean()) / df.total_amount.std()
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  VendorID tpep_pickup_datetime  \
# 0       9194462     9194462         2  2023-04-09 17:39:57
# 1      16987466    16987466         2  2023-01-26 14:47:44
# 2       6908899     6908899         2  2023-04-30 01:08:10
# 3       4617323     4617323         1  2023-05-19 17:10:40
# 4      14262454    14262454         2  2023-02-21 21:34:26
#
#   tpep_dropoff_datetime  passenger_count  trip_distance  RatecodeID  \
# 0   2023-04-09 18:13:31              2.0           9.81         1.0
# 1   2023-01-26 14:53:07              1.0           0.99         1.0
# 2   2023-04-30 01:20:46              2.0           2.85         1.0
# 3   2023-05-19 17:23:00              1.0           1.80         1.0
# 4   2023-02-21 21:38:01              1.0           1.23         1.0
#
#   store_and_fwd_flag  PULocationID  ...  tip_amount  tolls_amount  \
# 0                  N           132  ...        3.00           0.0
# 1                  N           170  ...        2.24           0.0
# 2                  N           114  ...        4.12           0.0
# 3                  N           229  ...        3.70           0.0
# 4                  N            48  ...        2.44           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee  \
# 0                    1.0         51.25                   0.0         1.75
# 1                    1.0         13.44                   2.5          NaN
# 2                    1.0         24.72                   2.5         0.00
# 3                    1.0         22.30                   2.5         0.00
# 4                    1.0         14.64                   2.5         0.00
#
#    airport_fee  passenger_count_corrected  total_amount_minmax  total_amount_z
# 0          NaN                        2.0             0.144661        1.027230
# 1          0.0                        1.0             0.027639       -0.679782
# 2          NaN                        2.0             0.062550       -0.170523
# 3          NaN                        1.0             0.055060       -0.279779
# 4          NaN                        1.0             0.031353       -0.625605
#
# [5 rows x 25 columns]

# %%
bin_names = ["cheap", "medium", "high", "expensive"]
df["price_range"]=  pd.cut(df.total_amount_minmax, [0,0.1, 0.2,0.3,1], labels=bin_names)
df.head(100)
#df[ (df["total_amount"] > 100)]
# Out:
#     Unnamed: 0.1  Unnamed: 0  VendorID tpep_pickup_datetime  \
# 0        9194462     9194462         2  2023-04-09 17:39:57
# 1       16987466    16987466         2  2023-01-26 14:47:44
# 2        6908899     6908899         2  2023-04-30 01:08:10
# 3        4617323     4617323         1  2023-05-19 17:10:40
# 4       14262454    14262454         2  2023-02-21 21:34:26
# ..           ...         ...       ...                  ...
# 95      15807946    15807946         2  2023-02-07 08:05:36
# 96      15272330    15272330         2  2023-02-11 21:50:50
# 97       8595585     8595585         2  2023-04-15 03:59:23
# 98      18699456    18699456         2  2023-01-09 21:06:20
# 99      16070144    16070144         2  2023-02-04 10:15:05
#
#    tpep_dropoff_datetime  passenger_count  trip_distance  RatecodeID  \
# 0    2023-04-09 18:13:31              2.0           9.81         1.0
# 1    2023-01-26 14:53:07              1.0           0.99         1.0
# 2    2023-04-30 01:20:46              2.0           2.85         1.0
# 3    2023-05-19 17:23:00              1.0           1.80         1.0
# 4    2023-02-21 21:38:01              1.0           1.23         1.0
# ..                   ...              ...            ...         ...
# 95   2023-02-07 08:14:06              1.0           1.77         1.0
# 96   2023-02-11 22:13:47              1.0           6.29         1.0
# 97   2023-04-15 03:59:26              1.0           0.00         5.0
# 98   2023-01-09 21:17:17              1.0           5.73         1.0
# 99   2023-02-04 10:19:05              1.0           0.61         1.0
#
#    store_and_fwd_flag  PULocationID  ...  tolls_amount  improvement_surcharge  \
# 0                   N           132  ...           0.0                    1.0
# 1                   N           170  ...           0.0                    1.0
# 2                   N           114  ...           0.0                    1.0
# 3                   N           229  ...           0.0                    1.0
# 4                   N            48  ...           0.0                    1.0
# ..                ...           ...  ...           ...                    ...
# 95                  N           158  ...           0.0                    1.0
# 96                  N            79  ...           0.0                    1.0
# 97                  N           263  ...           0.0                    1.0
# 98                  N            88  ...           0.0                    1.0
# 99                  N            75  ...           0.0                    1.0
#
#     total_amount  congestion_surcharge  Airport_fee  airport_fee  \
# 0          51.25                   0.0         1.75          NaN
# 1          13.44                   2.5          NaN          0.0
# 2          24.72                   2.5         0.00          NaN
# 3          22.30                   2.5         0.00          NaN
# 4          14.64                   2.5         0.00          NaN
# ..           ...                   ...          ...          ...
# 95         17.64                   2.5         0.00          NaN
# 96         41.40                   2.5         0.00          NaN
# 97         38.00                   0.0         0.00          NaN
# 98         32.70                   2.5          NaN          0.0
# 99          7.30                   0.0         0.00          NaN
#
#     passenger_count_corrected  total_amount_minmax  total_amount_z  \
# 0                         2.0             0.144661        1.027230
# 1                         1.0             0.027639       -0.679782
# 2                         2.0             0.062550       -0.170523
# 3                         1.0             0.055060       -0.279779
# 4                         1.0             0.031353       -0.625605
# ..                        ...                  ...             ...
# 95                        1.0             0.040638       -0.490164
# 96                        1.0             0.114175        0.582531
# 97                        1.0             0.103652        0.429031
# 98                        1.0             0.087249        0.189751
# 99                        1.0             0.008635       -0.956985
#
#     price_range
# 0        medium
# 1         cheap
# 2         cheap
# 3         cheap
# 4         cheap
# ..          ...
# 95        cheap
# 96       medium
# 97       medium
# 98        cheap
# 99        cheap
#
# [100 rows x 26 columns]

# %%
df["price_range_quantile"] = pd.qcut(df.total_amount_minmax,4, labels=bin_names)
df.head(100)
# Out:
#     Unnamed: 0.1  Unnamed: 0  VendorID tpep_pickup_datetime  \
# 0        9194462     9194462         2  2023-04-09 17:39:57
# 1       16987466    16987466         2  2023-01-26 14:47:44
# 2        6908899     6908899         2  2023-04-30 01:08:10
# 3        4617323     4617323         1  2023-05-19 17:10:40
# 4       14262454    14262454         2  2023-02-21 21:34:26
# ..           ...         ...       ...                  ...
# 95      15807946    15807946         2  2023-02-07 08:05:36
# 96      15272330    15272330         2  2023-02-11 21:50:50
# 97       8595585     8595585         2  2023-04-15 03:59:23
# 98      18699456    18699456         2  2023-01-09 21:06:20
# 99      16070144    16070144         2  2023-02-04 10:15:05
#
#    tpep_dropoff_datetime  passenger_count  trip_distance  RatecodeID  \
# 0    2023-04-09 18:13:31              2.0           9.81         1.0
# 1    2023-01-26 14:53:07              1.0           0.99         1.0
# 2    2023-04-30 01:20:46              2.0           2.85         1.0
# 3    2023-05-19 17:23:00              1.0           1.80         1.0
# 4    2023-02-21 21:38:01              1.0           1.23         1.0
# ..                   ...              ...            ...         ...
# 95   2023-02-07 08:14:06              1.0           1.77         1.0
# 96   2023-02-11 22:13:47              1.0           6.29         1.0
# 97   2023-04-15 03:59:26              1.0           0.00         5.0
# 98   2023-01-09 21:17:17              1.0           5.73         1.0
# 99   2023-02-04 10:19:05              1.0           0.61         1.0
#
#    store_and_fwd_flag  PULocationID  ...  improvement_surcharge  total_amount  \
# 0                   N           132  ...                    1.0         51.25
# 1                   N           170  ...                    1.0         13.44
# 2                   N           114  ...                    1.0         24.72
# 3                   N           229  ...                    1.0         22.30
# 4                   N            48  ...                    1.0         14.64
# ..                ...           ...  ...                    ...           ...
# 95                  N           158  ...                    1.0         17.64
# 96                  N            79  ...                    1.0         41.40
# 97                  N           263  ...                    1.0         38.00
# 98                  N            88  ...                    1.0         32.70
# 99                  N            75  ...                    1.0          7.30
#
#     congestion_surcharge  Airport_fee  airport_fee  passenger_count_corrected  \
# 0                    0.0         1.75          NaN                        2.0
# 1                    2.5          NaN          0.0                        1.0
# 2                    2.5         0.00          NaN                        2.0
# 3                    2.5         0.00          NaN                        1.0
# 4                    2.5         0.00          NaN                        1.0
# ..                   ...          ...          ...                        ...
# 95                   2.5         0.00          NaN                        1.0
# 96                   2.5         0.00          NaN                        1.0
# 97                   0.0         0.00          NaN                        1.0
# 98                   2.5          NaN          0.0                        1.0
# 99                   0.0         0.00          NaN                        1.0
#
#     total_amount_minmax  total_amount_z  price_range  price_range_quantile
# 0              0.144661        1.027230       medium             expensive
# 1              0.027639       -0.679782        cheap                 cheap
# 2              0.062550       -0.170523        cheap                  high
# 3              0.055060       -0.279779        cheap                  high
# 4              0.031353       -0.625605        cheap                 cheap
# ..                  ...             ...          ...                   ...
# 95             0.040638       -0.490164        cheap                medium
# 96             0.114175        0.582531       medium             expensive
# 97             0.103652        0.429031       medium             expensive
# 98             0.087249        0.189751        cheap             expensive
# 99             0.008635       -0.956985        cheap                 cheap
#
# [100 rows x 27 columns]

# %%
df["passenger_count_corrected"] = df["passenger_count"] 
df["passenger_count_corrected"].fillna(df["passenger_count"].median(), inplace=True)

# %%
df.price_range_quantile.unique()
# Out:
# ['expensive', 'cheap', 'high', 'medium']
# Categories (4, object): ['cheap' < 'medium' < 'high' < 'expensive']

# %% [markdown]
# ## Advanced Scaling

# %%
from  sklearn import preprocessing
out = preprocessing.MinMaxScaler().fit_transform(df[["total_amount"]])
np.squeeze(out)==df.total_amount_minmax
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 999995     True
# 999996     True
# 999997    False
# 999998     True
# 999999    False
# Name: total_amount_minmax, Length: 989697, dtype: bool

# %%
print(out[0],df.total_amount_minmax[0])
# Out:
# [0.1446611] 0.144661095636026

# %% [markdown]
# ### Take the precision into account and compare them if there almost samt

# %%
np.allclose(np.squeeze(out),df.total_amount_minmax)
# Out:
# True

# %% [markdown]
# ### If we have a lot of outliers
# We removed those above thought.... but this is anouther way.... using preprocessing

# %%
preprocessing.StandardScaler().fit_transform(df[["total_amount"]])
# Out:
# array([[ 1.02723048],
#        [-0.67978225],
#        [-0.1705227 ],
#        ...,
#        [ 1.37666921],
#        [ 0.39833105],
#        [-0.06758726]])
