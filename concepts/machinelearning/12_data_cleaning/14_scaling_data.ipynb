# %% [markdown]
# # 14 Scaling and Binding Numerical Data data
#
# Required modules:
# - pip install pandas
# - pip install numpy
# - pip install missingno
# - pip install scipy
# - pip install scikit-learn

# %%
import pandas as pd
import numpy as np

file = "../data/nyc_yellow_taxi_trip_selection.csv" # Takes about xx seconds...
#file = "../data/nyc_yellow_taxi_trip_records_from_Jan_to_Aug_2023.csv" # Huge takes almost 3 minutes to load

df = pd.read_csv(file, parse_dates=["tpep_pickup_datetime", "tpep_dropoff_datetime"] )
#df = pd.read_csv(file, usecols=["VendorID","tpep_pickup_datetime","tpep_dropoff_datetime","passenger_count","trip_distance","RatecodeID","PULocationID","DOLocationID","tip_amount","total_amount"], parse_dates=["tpep_pickup_datetime", "tpep_dropoff_datetime"] )
df = df.replace("NaN", np.nan)
df["passenger_count_corrected"] = df["passenger_count"] 
df["passenger_count_corrected"].fillna(df["passenger_count"].median(), inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  VendorID tpep_pickup_datetime  \
# 0       3560310     3560310         2  2023-05-29 15:40:01
# 1      16972558    16972558         1  2023-01-26 16:55:19
# 2       8617974     8617974         1  2023-04-14 23:14:24
# 3      17332136    17332136         2  2023-01-23 07:47:19
# 4      14128052    14128052         1  2023-02-23 08:49:52
#
#   tpep_dropoff_datetime  passenger_count  trip_distance  RatecodeID  \
# 0   2023-05-29 15:51:15              1.0           1.97         1.0
# 1   2023-01-26 17:01:28              2.0           0.30         1.0
# 2   2023-04-14 23:29:10              2.0           1.70         1.0
# 3   2023-01-23 08:10:05              1.0           8.31         1.0
# 4   2023-02-23 08:59:24              1.0           0.90         1.0
#
#   store_and_fwd_flag  PULocationID  ...  extra  mta_tax  tip_amount  \
# 0                  N           237  ...    0.0      0.5        3.50
# 1                  N           114  ...    5.0      0.5        2.00
# 2                  N           162  ...    3.5      0.5        2.50
# 3                  N           132  ...    0.0      0.5        7.45
# 4                  N           186  ...    2.5      0.5        0.00
#
#    tolls_amount  improvement_surcharge  total_amount  congestion_surcharge  \
# 0           0.0                    1.0          21.0                   2.5
# 1           0.0                    1.0          15.0                   2.5
# 2           0.0                    1.0          19.6                   2.5
# 3           0.0                    1.0          44.7                   0.0
# 4           0.0                    1.0          14.0                   2.5
#
#    Airport_fee  airport_fee  passenger_count_corrected
# 0          0.0          NaN                        1.0
# 1          NaN         0.00                        2.0
# 2          0.0          NaN                        2.0
# 3          NaN         1.25                        1.0
# 4          0.0          NaN                        1.0
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Remove extreme values (outliers)

# %%
from scipy import stats
q_low = df["total_amount"].quantile(0.01)
q_hi  = df["total_amount"].quantile(0.9999)

df = df[(df["total_amount"] < q_hi) & (df["total_amount"] > q_low)]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 989553 entries, 0 to 999999
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Unnamed: 0.1               989553 non-null  int64
#  1   Unnamed: 0                 989553 non-null  int64
#  2   VendorID                   989553 non-null  int64
#  3   tpep_pickup_datetime       989553 non-null  datetime64[ns]
#  4   tpep_dropoff_datetime      989553 non-null  datetime64[ns]
#  5   passenger_count            962619 non-null  float64
#  6   trip_distance              989553 non-null  float64
#  7   RatecodeID                 962619 non-null  float64
#  8   store_and_fwd_flag         962619 non-null  object
#  9   PULocationID               989553 non-null  int64
#  10  DOLocationID               989553 non-null  int64
#  11  payment_type               989553 non-null  int64
#  12  fare_amount                989553 non-null  float64
#  13  extra                      989553 non-null  float64
#  14  mta_tax                    989553 non-null  float64
#  15  tip_amount                 989553 non-null  float64
#  16  tolls_amount               989553 non-null  float64
#  17  improvement_surcharge      989553 non-null  float64
#  18  total_amount               989553 non-null  float64
#  19  congestion_surcharge       962619 non-null  float64
#  20  Airport_fee                811039 non-null  float64
#  21  airport_fee                151580 non-null  float64
#  22  passenger_count_corrected  989553 non-null  float64
# dtypes: datetime64[ns](2), float64(14), int64(6), object(1)
# memory usage: 181.2+ MB

# %% [markdown]
# ## Min-Max Scaling with:
# $$x' = \frac{x - \text{min}(x)}{\text{max}(x)-\text{min}(x)}

# %%
df["total_amount_minmax"] = (df.total_amount-df.total_amount.min()) / (df.total_amount.max()-df.total_amount.min())
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  VendorID tpep_pickup_datetime  \
# 0       3560310     3560310         2  2023-05-29 15:40:01
# 1      16972558    16972558         1  2023-01-26 16:55:19
# 2       8617974     8617974         1  2023-04-14 23:14:24
# 3      17332136    17332136         2  2023-01-23 07:47:19
# 4      14128052    14128052         1  2023-02-23 08:49:52
#
#   tpep_dropoff_datetime  passenger_count  trip_distance  RatecodeID  \
# 0   2023-05-29 15:51:15              1.0           1.97         1.0
# 1   2023-01-26 17:01:28              2.0           0.30         1.0
# 2   2023-04-14 23:29:10              2.0           1.70         1.0
# 3   2023-01-23 08:10:05              1.0           8.31         1.0
# 4   2023-02-23 08:59:24              1.0           0.90         1.0
#
#   store_and_fwd_flag  PULocationID  ...  mta_tax  tip_amount  tolls_amount  \
# 0                  N           237  ...      0.5        3.50           0.0
# 1                  N           114  ...      0.5        2.00           0.0
# 2                  N           162  ...      0.5        2.50           0.0
# 3                  N           132  ...      0.5        7.45           0.0
# 4                  N           186  ...      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee  \
# 0                    1.0          21.0                   2.5          0.0
# 1                    1.0          15.0                   2.5          NaN
# 2                    1.0          19.6                   2.5          0.0
# 3                    1.0          44.7                   0.0          NaN
# 4                    1.0          14.0                   2.5          0.0
#
#    airport_fee  passenger_count_corrected  total_amount_minmax
# 0          NaN                        1.0             0.049277
# 1         0.00                        2.0             0.031347
# 2          NaN                        2.0             0.045093
# 3         1.25                        1.0             0.120099
# 4          NaN                        1.0             0.028359
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Z-Score with
# $$x' = \frac{x - \bar{x}}{\sigma}

# %%
df["total_amount_z"] =  (df.total_amount - df.total_amount.mean()) / df.total_amount.std()
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  VendorID tpep_pickup_datetime  \
# 0       3560310     3560310         2  2023-05-29 15:40:01
# 1      16972558    16972558         1  2023-01-26 16:55:19
# 2       8617974     8617974         1  2023-04-14 23:14:24
# 3      17332136    17332136         2  2023-01-23 07:47:19
# 4      14128052    14128052         1  2023-02-23 08:49:52
#
#   tpep_dropoff_datetime  passenger_count  trip_distance  RatecodeID  \
# 0   2023-05-29 15:51:15              1.0           1.97         1.0
# 1   2023-01-26 17:01:28              2.0           0.30         1.0
# 2   2023-04-14 23:29:10              2.0           1.70         1.0
# 3   2023-01-23 08:10:05              1.0           8.31         1.0
# 4   2023-02-23 08:59:24              1.0           0.90         1.0
#
#   store_and_fwd_flag  PULocationID  ...  tip_amount  tolls_amount  \
# 0                  N           237  ...        3.50           0.0
# 1                  N           114  ...        2.00           0.0
# 2                  N           162  ...        2.50           0.0
# 3                  N           132  ...        7.45           0.0
# 4                  N           186  ...        0.00           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee  \
# 0                    1.0          21.0                   2.5          0.0
# 1                    1.0          15.0                   2.5          NaN
# 2                    1.0          19.6                   2.5          0.0
# 3                    1.0          44.7                   0.0          NaN
# 4                    1.0          14.0                   2.5          0.0
#
#    airport_fee  passenger_count_corrected  total_amount_minmax  total_amount_z
# 0          NaN                        1.0             0.049277       -0.339086
# 1         0.00                        2.0             0.031347       -0.609630
# 2          NaN                        2.0             0.045093       -0.402213
# 3         1.25                        1.0             0.120099        0.729564
# 4          NaN                        1.0             0.028359       -0.654721
#
# [5 rows x 25 columns]

# %%
bin_names = ["cheap", "medium", "high", "expensive"]
df["price_range"]=  pd.cut(df.total_amount_minmax, [0,0.1, 0.2,0.3,1], labels=bin_names)
df.head(100)
#df[ (df["total_amount"] > 100)]
# Out:
#     Unnamed: 0.1  Unnamed: 0  VendorID tpep_pickup_datetime  \
# 0        3560310     3560310         2  2023-05-29 15:40:01
# 1       16972558    16972558         1  2023-01-26 16:55:19
# 2        8617974     8617974         1  2023-04-14 23:14:24
# 3       17332136    17332136         2  2023-01-23 07:47:19
# 4       14128052    14128052         1  2023-02-23 08:49:52
# ..           ...         ...       ...                  ...
# 95      17562676    17562676         1  2023-01-20 20:36:07
# 96      18628976    18628976         2  2023-01-10 17:18:01
# 97      16283019    16283019         1  2023-02-02 12:38:52
# 98       1387911     1387911         2  2023-06-17 19:08:08
# 99       7127642     7127642         2  2023-04-28 09:33:46
#
#    tpep_dropoff_datetime  passenger_count  trip_distance  RatecodeID  \
# 0    2023-05-29 15:51:15              1.0           1.97         1.0
# 1    2023-01-26 17:01:28              2.0           0.30         1.0
# 2    2023-04-14 23:29:10              2.0           1.70         1.0
# 3    2023-01-23 08:10:05              1.0           8.31         1.0
# 4    2023-02-23 08:59:24              1.0           0.90         1.0
# ..                   ...              ...            ...         ...
# 95   2023-01-20 20:41:15              1.0           0.80         1.0
# 96   2023-01-10 17:35:35              1.0           2.15         1.0
# 97   2023-02-02 12:42:17              0.0           0.70         1.0
# 98   2023-06-17 19:20:01              4.0           0.89         1.0
# 99   2023-04-28 09:43:29              1.0           1.61         1.0
#
#    store_and_fwd_flag  PULocationID  ...  tolls_amount  improvement_surcharge  \
# 0                   N           237  ...           0.0                    1.0
# 1                   N           114  ...           0.0                    1.0
# 2                   N           162  ...           0.0                    1.0
# 3                   N           132  ...           0.0                    1.0
# 4                   N           186  ...           0.0                    1.0
# ..                ...           ...  ...           ...                    ...
# 95                  N           141  ...           0.0                    1.0
# 96                  N           142  ...           0.0                    1.0
# 97                  N           107  ...           0.0                    1.0
# 98                  N           246  ...           0.0                    1.0
# 99                  N            79  ...           0.0                    1.0
#
#     total_amount  congestion_surcharge  Airport_fee  airport_fee  \
# 0          21.00                   2.5          0.0          NaN
# 1          15.00                   2.5          NaN         0.00
# 2          19.60                   2.5          0.0          NaN
# 3          44.70                   0.0          NaN         1.25
# 4          14.00                   2.5          0.0          NaN
# ..           ...                   ...          ...          ...
# 95         13.80                   2.5          NaN         0.00
# 96         24.80                   2.5          NaN         0.00
# 97         11.75                   2.5          0.0          NaN
# 98         15.40                   2.5          0.0          NaN
# 99         15.40                   2.5          0.0          NaN
#
#     passenger_count_corrected  total_amount_minmax  total_amount_z  \
# 0                         1.0             0.049277       -0.339086
# 1                         2.0             0.031347       -0.609630
# 2                         2.0             0.045093       -0.402213
# 3                         1.0             0.120099        0.729564
# 4                         1.0             0.028359       -0.654721
# ..                        ...                  ...             ...
# 95                        1.0             0.027761       -0.663739
# 96                        1.0             0.060632       -0.167741
# 97                        0.0             0.021635       -0.756175
# 98                        4.0             0.032542       -0.591594
# 99                        1.0             0.032542       -0.591594
#
#     price_range
# 0         cheap
# 1         cheap
# 2         cheap
# 3        medium
# 4         cheap
# ..          ...
# 95        cheap
# 96        cheap
# 97        cheap
# 98        cheap
# 99        cheap
#
# [100 rows x 26 columns]

# %%
df["price_range_quantile"] = pd.qcut(df.total_amount_minmax,4, labels=bin_names)
df.head(100)
# Out:
#     Unnamed: 0.1  Unnamed: 0  VendorID tpep_pickup_datetime  \
# 0        3560310     3560310         2  2023-05-29 15:40:01
# 1       16972558    16972558         1  2023-01-26 16:55:19
# 2        8617974     8617974         1  2023-04-14 23:14:24
# 3       17332136    17332136         2  2023-01-23 07:47:19
# 4       14128052    14128052         1  2023-02-23 08:49:52
# ..           ...         ...       ...                  ...
# 95      17562676    17562676         1  2023-01-20 20:36:07
# 96      18628976    18628976         2  2023-01-10 17:18:01
# 97      16283019    16283019         1  2023-02-02 12:38:52
# 98       1387911     1387911         2  2023-06-17 19:08:08
# 99       7127642     7127642         2  2023-04-28 09:33:46
#
#    tpep_dropoff_datetime  passenger_count  trip_distance  RatecodeID  \
# 0    2023-05-29 15:51:15              1.0           1.97         1.0
# 1    2023-01-26 17:01:28              2.0           0.30         1.0
# 2    2023-04-14 23:29:10              2.0           1.70         1.0
# 3    2023-01-23 08:10:05              1.0           8.31         1.0
# 4    2023-02-23 08:59:24              1.0           0.90         1.0
# ..                   ...              ...            ...         ...
# 95   2023-01-20 20:41:15              1.0           0.80         1.0
# 96   2023-01-10 17:35:35              1.0           2.15         1.0
# 97   2023-02-02 12:42:17              0.0           0.70         1.0
# 98   2023-06-17 19:20:01              4.0           0.89         1.0
# 99   2023-04-28 09:43:29              1.0           1.61         1.0
#
#    store_and_fwd_flag  PULocationID  ...  improvement_surcharge  total_amount  \
# 0                   N           237  ...                    1.0         21.00
# 1                   N           114  ...                    1.0         15.00
# 2                   N           162  ...                    1.0         19.60
# 3                   N           132  ...                    1.0         44.70
# 4                   N           186  ...                    1.0         14.00
# ..                ...           ...  ...                    ...           ...
# 95                  N           141  ...                    1.0         13.80
# 96                  N           142  ...                    1.0         24.80
# 97                  N           107  ...                    1.0         11.75
# 98                  N           246  ...                    1.0         15.40
# 99                  N            79  ...                    1.0         15.40
#
#     congestion_surcharge  Airport_fee  airport_fee  passenger_count_corrected  \
# 0                    2.5          0.0          NaN                        1.0
# 1                    2.5          NaN         0.00                        2.0
# 2                    2.5          0.0          NaN                        2.0
# 3                    0.0          NaN         1.25                        1.0
# 4                    2.5          0.0          NaN                        1.0
# ..                   ...          ...          ...                        ...
# 95                   2.5          NaN         0.00                        1.0
# 96                   2.5          NaN         0.00                        1.0
# 97                   2.5          0.0          NaN                        0.0
# 98                   2.5          0.0          NaN                        4.0
# 99                   2.5          0.0          NaN                        1.0
#
#     total_amount_minmax  total_amount_z  price_range  price_range_quantile
# 0              0.049277       -0.339086        cheap                medium
# 1              0.031347       -0.609630        cheap                 cheap
# 2              0.045093       -0.402213        cheap                medium
# 3              0.120099        0.729564       medium             expensive
# 4              0.028359       -0.654721        cheap                 cheap
# ..                  ...             ...          ...                   ...
# 95             0.027761       -0.663739        cheap                 cheap
# 96             0.060632       -0.167741        cheap                  high
# 97             0.021635       -0.756175        cheap                 cheap
# 98             0.032542       -0.591594        cheap                 cheap
# 99             0.032542       -0.591594        cheap                 cheap
#
# [100 rows x 27 columns]

# %%
df["passenger_count_corrected"] = df["passenger_count"] 
df["passenger_count_corrected"].fillna(df["passenger_count"].median(), inplace=True)

# %%
df.price_range_quantile.unique()
# Out:
# ['medium', 'cheap', 'expensive', 'high']
# Categories (4, object): ['cheap' < 'medium' < 'high' < 'expensive']

# %% [markdown]
# ## Advanced Scaling

# %%
from  sklearn import preprocessing
out = preprocessing.MinMaxScaler().fit_transform(df[["total_amount"]])
np.squeeze(out)==df.total_amount_minmax
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 999995     True
# 999996    False
# 999997    False
# 999998    False
# 999999    False
# Name: total_amount_minmax, Length: 989553, dtype: bool

# %%
print(out[0],df.total_amount_minmax[0])
# Out:
# [0.04927683] 0.0492768348075544

# %% [markdown]
# ### Take the precision into account and compare them if there almost samt

# %%
np.allclose(np.squeeze(out),df.total_amount_minmax)
# Out:
# True

# %% [markdown]
# ### If we have a lot of outliers
# We removed those above thought.... but this is anouther way.... using preprocessing

# %%
preprocessing.StandardScaler().fit_transform(df[["total_amount"]])
# Out:
# array([[-0.33908635],
#        [-0.60963073],
#        [-0.40221337],
#        ...,
#        [-0.37741347],
#        [-0.52846742],
#        [ 3.09772917]])
